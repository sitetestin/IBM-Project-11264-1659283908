# %% [markdown]
# # Basic Python

# %% [markdown]
# ## 1. Split this string

# %%
s = "Hi there Sam!"

# %%
x= s.split()
print(x)

# %% [markdown]
# ## 2. Use .format() to print the following string.
#
# ### Output should be: The diameter of Earth is 12742 kilometers.

# %%
planet = "Earth"
diameter = 12742

# %%
txt = "The diameter of Earth is {} kilometers".format(diameter)

print(txt)

# %% [markdown]
# ## 3. In this nest dictionary grab the word "hello"

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
print(  d['k1'][3]['tricky'][3]['target'][3])

# %% [markdown]
# # Numpy

# %%
import numpy as np

# %% [markdown]
# ## 4.1 Create an array of 10 zeros?
# ## 4.2 Create an array of 10 fives?

# %%
array=np.zeros(10)
print(array)

# %%
array=np.ones(10)*5
print(array)

# %% [markdown]
# ## 5. Create an array of all the even integers from 20 to 35

# %%
array=np.arange(20,36,2)
print(array)

# %% [markdown]
# ## 6. Create a 3x3 matrix with values ranging from 0 to 8

# %%
x =  np.arange(0, 9).reshape(3,3)
print(x)

# %% [markdown]
# ## 7. Concatenate a and b
# a = np.array([1, 2, 3]), b = np.array([4, 5, 6])

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

# %%
c=np.concatenate((a, b), axis=None)
print(c)

# %% [markdown]
# # Pandas

# %% [markdown]
# ## 8. Create a dataframe with 3 rows and 2 columns

# %%
import pandas as pd

# %%
df = pd.DataFrame( columns=['col1','col2'], index=['row1','row2','row3'] )
print(df)

# %% [markdown]
# ## 9. Generate the series of dates from 1st Jan, 2023 to 10th Feb, 2023

# %%
from datetime import datetime
print(pd.date_range(start="2023-01-01",end="2023-02-10"))

# %% [markdown]
# ## 10. Create 2D list to DataFrame
#
# lists = [[1, 'aaa', 22],
#          [2, 'bbb', 25],
#          [3, 'ccc', 24]]

# %%
lists = [[1, 'aaa', 22], [2, 'bbb', 25], [3, 'ccc', 24]]

# %%
df = pd.DataFrame(lists, columns =['key', 'values','num']) 
print(df)
